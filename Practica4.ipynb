# %% [markdown]
# Seleccionar al menos tres modelos de clasificación, por ejemplo: Random forest,
# gradient boost, regresión logística para clasificar este dataset.

# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

# %%
iris = load_iris()
X, y = iris['data'], iris['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, shuffle=True
)

# %%
lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

accuracy_score(y_test, y_pred)
precision_score(y_test, y_pred, average='macro')
recall_score(y_test, y_pred, average='macro')
f1_score(y_test, y_pred, average='macro')
confusion_matrix(y_test, y_pred)
# Out:
# array([[17,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  0, 16]])

# %%
cv = GridSearchCV(RandomForestClassifier(), {
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 20]
}, cv=5, scoring='accuracy')

cv.fit(X_train, y_train)

cv.best_score_
# Out:
# np.float64(0.9428571428571428)

# %%
y_pred = cv.predict(X_test)

accuracy_score(y_test, y_pred)
f1_score(y_test, y_pred, average='macro')
# Out:
# 1.0

# %%
cv = GridSearchCV(GradientBoostingClassifier(), {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.05, 0.1, 0.2]
}, cv=5, scoring='accuracy')

cv.fit(X_train, y_train)

cv.best_score_
# Out:
# np.float64(0.9333333333333333)

# %%
y_pred = cv.predict(X_test)

accuracy_score(y_test, y_pred)
f1_score(y_test, y_pred, average='macro')
# Out:
# 1.0

# %%
cv = RandomizedSearchCV(RandomForestClassifier(), {
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 20]
}, cv=5, scoring='accuracy')

cv.fit(X_train, y_train)

cv.best_score_
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# np.float64(0.9333333333333333)

# %%
y_pred = cv.predict(X_test)

accuracy_score(y_test, y_pred)
f1_score(y_test, y_pred, average='macro')
# Out:
# 1.0

# %%
cv = RandomizedSearchCV(GradientBoostingClassifier(), {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.05, 0.1, 0.2]
}, cv=5, scoring='accuracy')

cv.fit(X_train, y_train)

cv.best_score_
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# np.float64(0.9238095238095239)

# %%
y_pred = cv.predict(X_test)

accuracy_score(y_test, y_pred)
f1_score(y_test, y_pred, average='macro')
# Out:
# 1.0
